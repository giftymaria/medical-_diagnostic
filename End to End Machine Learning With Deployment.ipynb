# %% [markdown]
# # End to End Machine Learning With Deployment

# %% [markdown]
# ### Part1- EDA of the Medical Dataset
# 1. Import the libraries
# 2. Load and View the data
# 3. Clean the data
# 4. Complete EDA of the data ( depoloy a EDA page in streamlit)
#
# ### Part2-Modelling of the data set
# 5. Preprocessing for modelling
# 6. Fit and Evaluate various models
# 7. OPtimize the chosen model
# 8. Interpret the model
# 9. Create a pipeline for the model
# 10. Pickle the model
# 11. Deploy the model in streamlit

# %% [markdown]
# ### Step1. Import the libraries

# %%
pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\gods gift\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\gods gift\anaconda3\lib\site-packages (from imbalanced-learn) (1.21.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\gods gift\anaconda3\lib\site-packages (from imbalanced-learn) (1.9.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\gods gift\anaconda3\lib\site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gods gift\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\gods gift\anaconda3\lib\site-packages (from imbalanced-learn) (1.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\gods gift\anaconda3\lib\site-packages (1.7.5)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy in c:\users\gods gift\anaconda3\lib\site-packages (from xgboost) (1.21.5)
# Requirement already satisfied: scipy in c:\users\gods gift\anaconda3\lib\site-packages (from xgboost) (1.9.1)

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\gods gift\anaconda3\lib\site-packages (1.20.0)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (4.11.3)
# Requirement already satisfied: python-dateutil in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: pympler>=0.9 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: tornado>=6.0.3 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: pandas<2,>=0.25 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (1.4.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (13.3.2)
# Requirement already satisfied: requests>=2.4 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: toml in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: semver in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (2.13.0)
# Requirement already satisfied: cachetools>=4.0 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: altair<5,>=3.2.0 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (3.1.31)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (4.3.0)
# Requirement already satisfied: watchdog in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: packaging>=14.1 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (21.3)
# Requirement already satisfied: click>=7.0 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: validators>=0.2 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (0.20.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (9.2.0)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: blinker>=1.0.0 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (1.5)
# Requirement already satisfied: tzlocal>=1.1 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (4.2)
# Requirement already satisfied: numpy in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (1.21.5)
# Requirement already satisfied: toolz in c:\users\gods gift\anaconda3\lib\site-packages (from altair<5,>=3.2.0->streamlit) (0.11.2)
# Requirement already satisfied: entrypoints in c:\users\gods gift\anaconda3\lib\site-packages (from altair<5,>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\gods gift\anaconda3\lib\site-packages (from altair<5,>=3.2.0->streamlit) (4.16.0)
# Requirement already satisfied: jinja2 in c:\users\gods gift\anaconda3\lib\site-packages (from altair<5,>=3.2.0->streamlit) (2.11.3)
# Requirement already satisfied: colorama in c:\users\gods gift\anaconda3\lib\site-packages (from click>=7.0->streamlit) (0.4.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\gods gift\anaconda3\lib\site-packages (from gitpython!=3.1.19->streamlit) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in c:\users\gods gift\anaconda3\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\gods gift\anaconda3\lib\site-packages (from packaging>=14.1->streamlit) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gods gift\anaconda3\lib\site-packages (from pandas<2,>=0.25->streamlit) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\gods gift\anaconda3\lib\site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\gods gift\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gods gift\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gods gift\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gods gift\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (3.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\gods gift\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\gods gift\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit) (2.14.0)
# Requirement already satisfied: tzdata in c:\users\gods gift\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit) (2022.7)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\gods gift\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\gods gift\anaconda3\lib\site-packages (from validators>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\gods gift\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\gods gift\anaconda3\lib\site-packages (from jinja2->altair<5,>=3.2.0->streamlit) (2.0.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\gods gift\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\gods gift\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (21.4.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\gods gift\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->streamlit) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')
print("All needed libraries are imported")


# libraries for preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from imblearn.over_sampling import SMOTE

# libraries for modeling
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn. tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC

# libraries for model evaluation
from sklearn.metrics import accuracy_score,precision_score,recall_score, f1_score,roc_auc_score
from sklearn.metrics import confusion_matrix,classification_report,plot_roc_curve,plot_precision_recall_curve,plot_confusion_matrix


#library for deployement
import streamlit as st
# Out:
# All needed libraries are imported

# %% [markdown]
# ### Step2. Load and View the data

# %%
data=pd.read_csv('data.csv')
data.head(10)
# Out:
#    Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0           0            6      148             72             35        0
# 1           1            1       85             66             29        0
# 2           2            8      183             64              0        0
# 3           3            1       89             66             23       94
# 4           4            0      137             40             35      168
# 5           5            5      116             74              0        0
# 6           6            3       78             50             32       88
# 7           7           10      115              0              0        0
# 8           8            2      197             70             45      543
# 9           9            8      125             96              0        0
#
#     BMI  DiabetesPedigreeFunction  Age Outcome
# 0  33.6                     0.627   50     Yes
# 1  26.6                     0.351   31      No
# 2  23.3                     0.672   32     Yes
# 3  28.1                     0.167   21      No
# 4  43.1                     2.288   33     Yes
# 5  25.6                     0.201   30      No
# 6  31.0                     0.248   26     Yes
# 7  35.3                     0.134   29      No
# 8  30.5                     0.158   53     Yes
# 9   0.0                     0.232   54     Yes

# %%
data.shape
# Out:
# (768, 10)

# %%
data.dtypes
# Out:
# Unnamed: 0                    int64
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                      object
# dtype: object

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                  0
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data[~data.applymap(np.isreal).any(1)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
data.describe().T
# Out:
#                           count        mean         std     min        25%  \
# Unnamed: 0                768.0  383.500000  221.846794   0.000  191.75000
# Pregnancies               768.0    3.845052    3.369578   0.000    1.00000
# Glucose                   768.0  120.894531   31.972618   0.000   99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000   62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000    0.00000
# Insulin                   768.0   79.799479  115.244002   0.000    0.00000
# BMI                       768.0   31.992578    7.884160   0.000   27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078    0.24375
# Age                       768.0   33.240885   11.760232  21.000   24.00000
#
#                                50%        75%     max
# Unnamed: 0                383.5000  575.25000  767.00
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# SkinThickness              23.0000   32.00000   99.00
# Insulin                    30.5000  127.25000  846.00
# BMI                        32.0000   36.60000   67.10
# DiabetesPedigreeFunction    0.3725    0.62625    2.42
# Age                        29.0000   41.00000   81.00

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Pregnancies', 'Glucose', 'BloodPressure',
#        'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age',
#        'Outcome'],
#       dtype='object')

# %% [markdown]
# **Observations**
# 1. Data has 768 rows and 10 columns
# 2. The first column is 'Unnamed: 0' which is redundant
# 3. All columns are numerical except the Outcome
# 4. There are no nulls in the data
# 5. However there are nulls present as 0's
# 6. There are no duplicates or corrupt characters

# %% [markdown]
# ### Step 3. Clean the data

# %%
# remove the redundant columns
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data.head(2)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age Outcome
# 0                     0.627   50     Yes
# 1                     0.351   31      No

# %%
zerofill=lambda x:x.replace(0, x.median())
cols=data.columns[1:6]
data[cols]=data[cols].apply(zerofill, axis=0)

# %%
data.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  121.656250   30.438286  44.000  99.75000
# BloodPressure             768.0   72.386719   12.096642  24.000  64.00000
# SkinThickness             768.0   27.334635    9.229014   7.000  23.00000
# Insulin                   768.0   94.652344  105.547598  14.000  30.50000
# BMI                       768.0   32.450911    6.875366  18.200  27.50000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# SkinThickness              23.0000   32.00000   99.00
# Insulin                    31.2500  127.25000  846.00
# BMI                        32.0000   36.60000   67.10
# DiabetesPedigreeFunction    0.3725    0.62625    2.42
# Age                        29.0000   41.00000   81.00

# %%
d={'Yes':1, 'No':0}
df=data.copy()
df['Outcome']=df['Outcome'].map(d)

# %%
df.head(2)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35     30.5  33.6
# 1            1       85             66             29     30.5  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0

# %% [markdown]
# ### Step4. Complete EDA of the data ( depoloy a EDA page in streamlit)

# %% [markdown]
# **Univariate Analysis**
# 1. Numericals -histograms and boxplots
# 2. Categorical- barcharts
#
# **Bivariate Analysis**
# 1. Categorical vs Numerical barchart
# 2. Scatter plots and Line plots
# 3. Pairplots
#
# **Corralations**
# 1. Correlation Matrix
# 2. Heatmap

# %% [markdown]
# **Univariate Analysis**

# %%
def histograms(data):
    print('Histograms')
    data.hist()
    plt.tight_layout()
    plt.show()

# %%
histograms(df)
# Out:
# Histograms

# %%
def boxplot_histplot(data, feature, bins=None, figsize=(12,7)):
    print("Boxplot and Histplot for ", feature)
    fig, (ax_box, ax_hist)=plt.subplots(
    nrows=2,
    sharex=True,
    gridspec_kw={'height_ratios':(0.25, 0.75)},
    figsize=figsize)
    
    sns.boxplot(data=data, x=feature, showmeans=True, color='orange', ax=ax_box)
    sns.histplot(data=data, x=feature, bins=bins, ax=ax_hist, pallete='green') if bins else sns.\
                         histplot(data=data, x=feature, ax=ax_hist)
    ax_hist.axvline(data[feature].mean(), color='green', linestyle='--')
    ax_hist.axvline(data[feature].median(), color='black', linestyle='-')
    plt.show()

# %%
for col in data.select_dtypes(exclude='O').columns:
    boxplot_histplot(data=data, feature=col, bins=None, figsize=(12,7))
# Out:
# Boxplot and Histplot for  Pregnancies
# Boxplot and Histplot for  Glucose
# Boxplot and Histplot for  BloodPressure
# Boxplot and Histplot for  SkinThickness
# Boxplot and Histplot for  Insulin
# Boxplot and Histplot for  BMI
# Boxplot and Histplot for  DiabetesPedigreeFunction
# Boxplot and Histplot for  Age

# %%
def barchart(data, feature):
    print("Univariate Countplot of ", feature)
    plt.figure(figsize=(12,7))
    ax=sns.countplot(data=data, x=feature, color='green')
    for p in ax.patches:
        x=p.get_bbox().get_points()[:,0]
        y=p.get_bbox().get_points()[1,1]
        ax.annotate("{:.3g}%".format(100.*y/len(df)), (x.mean(), y), ha='center', va='bottom')
    plt.show()

# %%
barchart(data=data, feature='Outcome')
# Out:
# Univariate Countplot of  Outcome

# %% [markdown]
# **Observations**
# 1. Insulin . DPF and Age are highly right skewed and having heavy amoiunt of outliers ( we may need to do data transformation like log)
# 2. Age and Pregnancies are also right skewed with some extreme values which may be legit ( need to consukt with domain experts)
# 3. Outcome variable is highly imbalanced(Yes:No = 1:2) , we need to solve for data imbalance before modelling
# 4. Missing values have been taken care of
# 5. Label Encoding is done

# %% [markdown]
# **Bivariate Analysis**
# 1. Categorical vs Numerical barchart
# 2. Scatter plots and Line plots
# 3. Pairplots

# %%
def catnum(data, feature1, feature2):
    print("Bivariate Barchart between {0} and {1}".format(feature1, feature2))
    data.groupby(feature1)[feature2].mean().plot(kind='bar', color='orange')
    plt.ylabel(col)
    plt.show()

# %%
for col in data.select_dtypes(exclude='O').columns:
    catnum(data=data, feature1='Outcome', feature2=col)
# Out:
# Bivariate Barchart between Outcome and Pregnancies
# Bivariate Barchart between Outcome and Glucose
# Bivariate Barchart between Outcome and BloodPressure
# Bivariate Barchart between Outcome and SkinThickness
# Bivariate Barchart between Outcome and Insulin
# Bivariate Barchart between Outcome and BMI
# Bivariate Barchart between Outcome and DiabetesPedigreeFunction
# Bivariate Barchart between Outcome and Age

# %%
def lineplot_scatterplot(data, feature1, feature2):
    plt.figure(figsize=(16,7))
    print("Bivariate Charts for {0} and {1}".format(feature1, feature2))
    plt.subplot(1,2,1)
    sns.lineplot(data=data, x=feature1, y=feature2, color='green')
    plt.title('Lineplot between features')
    
    plt.subplot(1,2,2)
    sns.scatterplot(data=data, x=feature1, y=feature2, color='orange')
    plt.title('Scatterplot between features')
    plt.show()

# %%
for col in df.select_dtypes(exclude='O').columns:
    lineplot_scatterplot(data=df, feature1='Glucose', feature2=col)
# Out:
# Bivariate Charts for Glucose and Pregnancies
# Bivariate Charts for Glucose and Glucose
# Bivariate Charts for Glucose and BloodPressure
# Bivariate Charts for Glucose and SkinThickness
# Bivariate Charts for Glucose and Insulin
# Bivariate Charts for Glucose and BMI
# Bivariate Charts for Glucose and DiabetesPedigreeFunction
# Bivariate Charts for Glucose and Age
# Bivariate Charts for Glucose and Outcome

# %%
sns.pairplot(df, kind='reg')

# %% [markdown]
# **Corralations**
# 1. Correlation Matrix
# 2. Heatmap

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.128213       0.208615       0.032568
# Glucose                      0.128213  1.000000       0.218937       0.172143
# BloodPressure                0.208615  0.218937       1.000000       0.147809
# SkinThickness                0.032568  0.172143       0.147809       1.000000
# Insulin                     -0.055697  0.357573      -0.028721       0.238188
# BMI                          0.021546  0.231400       0.281132       0.546951
# DiabetesPedigreeFunction    -0.033523  0.137327      -0.002378       0.142977
# Age                          0.544341  0.266909       0.324915       0.054514
# Outcome                      0.221898  0.492782       0.165723       0.189065
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.055697  0.021546                 -0.033523
# Glucose                   0.357573  0.231400                  0.137327
# BloodPressure            -0.028721  0.281132                 -0.002378
# SkinThickness             0.238188  0.546951                  0.142977
# Insulin                   1.000000  0.189022                  0.178029
# BMI                       0.189022  1.000000                  0.153506
# DiabetesPedigreeFunction  0.178029  0.153506                  1.000000
# Age                      -0.015413  0.025744                  0.033561
# Outcome                   0.148457  0.312249                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.266909  0.492782
# BloodPressure             0.324915  0.165723
# SkinThickness             0.054514  0.189065
# Insulin                  -0.015413  0.148457
# BMI                       0.025744  0.312249
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %%
df[df.columns[:]].corr()['Outcome']
# Out:
# Pregnancies                 0.221898
# Glucose                     0.492782
# BloodPressure               0.165723
# SkinThickness               0.189065
# Insulin                     0.148457
# BMI                         0.312249
# DiabetesPedigreeFunction    0.173844
# Age                         0.238356
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df.corr(), annot=True, cmap='Spectral', vmin=-1, vmax=+1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations of Bivariate Analysis**
# 1. Women with higher Pregnancies, Glucose, DPF, Insulin are more likely to be diabetic
# 2. Glucose and Insulin, BMI and SkinThickness appear to have hiugh multicollinearity
# 3. Glucose, BMI appear to be strongest predictors of Diabetes

# %% [markdown]
# ### App for EDA

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\gods gift\anaconda3\lib\site-packages (1.20.0)
# Requirement already satisfied: validators>=0.2 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (0.20.0)
# Requirement already satisfied: python-dateutil in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (3.1.31)
# Requirement already satisfied: tornado>=6.0.3 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: cachetools>=4.0 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: click>=7.0 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: requests>=2.4 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: packaging>=14.1 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (9.2.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (4.3.0)
# Requirement already satisfied: blinker>=1.0.0 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (1.5)
# Requirement already satisfied: watchdog in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: tzlocal>=1.1 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (4.2)
# Requirement already satisfied: semver in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (2.13.0)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (4.11.3)
# Requirement already satisfied: pympler>=0.9 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: altair<5,>=3.2.0 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: numpy in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (1.21.5)
# Requirement already satisfied: pandas<2,>=0.25 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (1.4.4)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (13.3.2)
# Requirement already satisfied: toml in c:\users\gods gift\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: toolz in c:\users\gods gift\anaconda3\lib\site-packages (from altair<5,>=3.2.0->streamlit) (0.11.2)
# Requirement already satisfied: jinja2 in c:\users\gods gift\anaconda3\lib\site-packages (from altair<5,>=3.2.0->streamlit) (2.11.3)
# Requirement already satisfied: entrypoints in c:\users\gods gift\anaconda3\lib\site-packages (from altair<5,>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\gods gift\anaconda3\lib\site-packages (from altair<5,>=3.2.0->streamlit) (4.16.0)
# Requirement already satisfied: colorama in c:\users\gods gift\anaconda3\lib\site-packages (from click>=7.0->streamlit) (0.4.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\gods gift\anaconda3\lib\site-packages (from gitpython!=3.1.19->streamlit) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in c:\users\gods gift\anaconda3\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\gods gift\anaconda3\lib\site-packages (from packaging>=14.1->streamlit) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gods gift\anaconda3\lib\site-packages (from pandas<2,>=0.25->streamlit) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\gods gift\anaconda3\lib\site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gods gift\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\gods gift\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gods gift\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gods gift\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (1.26.11)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\gods gift\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\gods gift\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit) (2.14.0)
# Requirement already satisfied: tzdata in c:\users\gods gift\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit) (2022.7)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\gods gift\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\gods gift\anaconda3\lib\site-packages (from validators>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\gods gift\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\gods gift\anaconda3\lib\site-packages (from jinja2->altair<5,>=3.2.0->streamlit) (2.0.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\gods gift\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\gods gift\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\gods gift\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->streamlit) (0.1.2)

# %%
# %%writefile eda.py
import streamlit as st
st.title("The EDA Page")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
st.set_option('deprecation.showPyplotGlobalUse', False)
plt.style.use('fivethirtyeight')

### Step2. Load and View the data

data=pd.read_csv('data.csv')
st.subheader('Data View')
st.write(data.head())

st.subheader('Descriptives')
st.write(data.describe().T)

data.hist()
st.subheader('Histograms')
plt.tight_layout()
st.pyplot()
# Out:
# Overwriting eda.py

# %% [markdown]
# # End of Part 1

# %% [markdown]
# # step 5:data preproccesing
# 1. separate features and the labels
# 2. null value imputation
# 3. label encoding
# 4. data imbalanced solving
# 5. train test split
# 6. feature scaling

# %%
def preprocess(data,label):
    x=data.drop(label,axis=1)
    y=data[label]
    sm=SMOTE()
    x,y=sm.fit_resample(x,y)
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
    return x_train,x_test,y_train,y_test

# %%
x_train,x_test,y_train,y_test=process(df,'Outcome')

# %%
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %% [markdown]
# # Step 6
#
# Fit and evalute models

# %%
def print_metrics(y_test,y_pred,model_name):
    print('the results of the model',model_name)
    print('')
    print('accuracy_score=',accuracy_score(y_test,y_pred))
    print('')
    print('recall_score=',recall_score(y_test,y_pred))
    print('')
    print('precision=',precision_score(y_test,y_pred))
    print('')
    print('f1_score=',f1_score(y_test,y_pred))

# %%
def plot_metrics(clf,x_test,y_test,model_name):
    plot_confusion_matrix(clf,x_test,y_test,display_labels=[0,1])
    print('')
    plot_roc_curve(clf,x_test,y_test)
    print('')
    plot_precision_recall_curve(clf,x_test,y_test)

# %%
y=df['Outcome']
y.value_counts()
x=df.drop('Outcome',axis=1)

# %%
sm=SMOTE()
x,y=sm.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 1    500
# 0    500
# Name: Outcome, dtype: int64

# %%
#fit the knn method
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
print_metrics(y_pred,y_test,'KNN')
# Out:
# the results of the model KNN
#
# accuracy_score= 0.785
#
# recall_score= 0.75
#
# precision= 0.8613861386138614
#
# f1_score= 0.8018433179723503

# %%
plot_metrics(knn,x_test, y_test,'KNN')

# %%
#optimize k
neighbors=np.arange(1,20)
train_accuracies=np.empty(len(neighbors))
test_accuracies=np.empty(len(neighbors))

for i,k in enumerate(neighbors):
    knn=KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train,y_train)
    train_accuracies[i]=knn.score(x_train,y_train)
    test_accuracies[i]=knn.score(x_test,y_test)

plt.plot(neighbors, train_accuracies, label='Train_accuracies')
plt.plot(neighbors, test_accuracies, label='Test_accuracies')
plt.legend()
plt.title("Model Complexity Curves")
plt.xlabel("No.of.Neighbors")
plt.ylabel("Accuraries")
plt.show()

# %%
#refit the model

knn=KNeighborsClassifier(n_neighbors=16)
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
print_metrics(y_pred,y_test,'KNN')
# Out:
# the results of the model KNN
#
# accuracy_score= 0.765
#
# recall_score= 0.7327586206896551
#
# precision= 0.8415841584158416
#
# f1_score= 0.7834101382488479

# %% [markdown]
# # fit and evaluate all the modeland choose the best to deploy

# %%
clfs = {
    'LogisticRegression': LogisticRegression(),
    'Naive Bayes': GaussianNB(),
    'KNN':KNeighborsClassifier(),
    'DecisionTreeClassifier': DecisionTreeClassifier(),
    'RandomForestClassifier':RandomForestClassifier(),
    'AdaBoostClassifier':AdaBoostClassifier(),
    'GradientBoostingClassifier':GradientBoostingClassifier(),
    'XGBClassifier':XGBClassifier(),
    'SVM':SVC()
}

# create an empty dataframe of metrics
models_report = pd.DataFrame(columns=['Model_name','Accuracy','Recall','Precision',
                                    'f1_score'])

# fit and evaluate each model
for clf, clf_name in list(zip(clfs.values(), clfs.keys())):
    clf.fit(x_train, y_train)
    print('Fitting Classifier....', clf_name)
    y_pred=clf.predict(x_test)
    t=pd.Series({
        'Model_name':clf_name,
        'Accuracy':accuracy_score(y_test, y_pred),
        'Recall':recall_score(y_test, y_pred),
        'Precision':precision_score(y_test, y_pred),
        'f1_score':f1_score(y_test, y_pred)
    })
    models_report = models_report.append(t, ignore_index=True)
    
models_report=models_report.sort_values(by='f1_score', ascending=False)
models_report
# Out:
# Fitting Classifier.... LogisticRegression
# Fitting Classifier.... Naive Bayes
# Fitting Classifier.... KNN
# Fitting Classifier.... DecisionTreeClassifier
# Fitting Classifier.... RandomForestClassifier
# Fitting Classifier.... AdaBoostClassifier
# Fitting Classifier.... GradientBoostingClassifier
# Fitting Classifier.... XGBClassifier
# Fitting Classifier.... SVM
#                    Model_name  Accuracy    Recall  Precision  f1_score
# 2                         KNN     0.785  0.861386   0.750000  0.801843
# 4      RandomForestClassifier     0.790  0.831683   0.770642  0.800000
# 3      DecisionTreeClassifier     0.785  0.841584   0.758929  0.798122
# 7               XGBClassifier     0.775  0.831683   0.750000  0.788732
# 8                         SVM     0.770  0.801980   0.757009  0.778846
# 6  GradientBoostingClassifier     0.765  0.811881   0.745455  0.777251
# 5          AdaBoostClassifier     0.765  0.801980   0.750000  0.775120
# 0          LogisticRegression     0.750  0.762376   0.747573  0.754902
# 1                 Naive Bayes     0.745  0.693069   0.777778  0.732984

# %%
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#optimize the model using GridSearchCV
param_grid={
    'n_estimators':[100,150,200,250,300],
    'min_samples_leaf':range(1,5,1),
    'min_samples_split':range(2,10,2),
    'max_depth':[1,2,3,4,5],
    'criterion':['entropy','gini'],
    
}
n_folds=3
cv=GridSearchCV(estimator=rfc,param_grid=param_grid,cv=n_folds,n_jobs=-1,verbose=5,return_train_score=False)
cv.fit(x_train,y_train)
cv.best_score_
# Out:
# Fitting 3 folds for each of 800 candidates, totalling 2400 fits
# 0.8100072278073461

# %%
#lets interupt the model
rfc_tuned=cv.best_estimator_
rfc_tuned
# Out:
# RandomForestClassifier(max_depth=5, min_samples_split=8, n_estimators=150)

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.41.0-cp39-cp39-win_amd64.whl (435 kB)
#      -------------------------------------- 435.6/435.6 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\users\gods gift\anaconda3\lib\site-packages (from shap) (1.9.1)
# Requirement already satisfied: numpy in c:\users\gods gift\anaconda3\lib\site-packages (from shap) (1.21.5)
# Requirement already satisfied: scikit-learn in c:\users\gods gift\anaconda3\lib\site-packages (from shap) (1.0.2)
# Requirement already satisfied: packaging>20.9 in c:\users\gods gift\anaconda3\lib\site-packages (from shap) (21.3)
# Requirement already satisfied: cloudpickle in c:\users\gods gift\anaconda3\lib\site-packages (from shap) (2.0.0)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\gods gift\anaconda3\lib\site-packages (from shap) (4.64.1)
# Requirement already satisfied: pandas in c:\users\gods gift\anaconda3\lib\site-packages (from shap) (1.4.4)
# Requirement already satisfied: numba in c:\users\gods gift\anaconda3\lib\site-packages (from shap) (0.55.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\gods gift\anaconda3\lib\site-packages (from packaging>20.9->shap) (3.0.9)
# Requirement already satisfied: colorama in c:\users\gods gift\anaconda3\lib\site-packages (from tqdm>4.25.0->shap) (0.4.5)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\gods gift\anaconda3\lib\site-packages (from numba->shap) (0.38.0)
# Requirement already satisfied: setuptools in c:\users\gods gift\anaconda3\lib\site-packages (from numba->shap) (63.4.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gods gift\anaconda3\lib\site-packages (from pandas->shap) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\gods gift\anaconda3\lib\site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gods gift\anaconda3\lib\site-packages (from scikit-learn->shap) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\gods gift\anaconda3\lib\site-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\gods gift\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.41.0 slicer-0.0.7

# %%
#feature importance / model interpretation

import shap
value=shap.TreeExplainer(rfc).shap_values(x_test)
shap.summary_plot(value, x_train, plot_type='bar', feature_names=x.columns)

# %%
# Create the deployement model pipeline

from sklearn.pipeline import Pipeline

# %%
sc=StandardScaler()
rfc=rfc_tuned
steps=[('sc',sc),('rfc',rfc)]
pipeline=Pipeline(steps)
x_train,x_test,y_train,y_test=preprocess(df,'Outcome')
pipeline.fit(x_train,y_train)
y_pred=pipeline.predict(x_test)
print_metrics(y_test,y_pred,'Pipeline RFC')
# Out:
# the results of the model Pipeline RFC
#
# accuracy_score= 0.79
#
# recall_score= 0.8514851485148515
#
# precision= 0.7610619469026548
#
# f1_score= 0.8037383177570093

# %%
#To freeze the model
import pickle
model=open('rfc.pickle','wb')
pickle.dump(pipeline,model)
model.close()

# %% [markdown]
# # Deploy pickle model

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import pickle
st.title('Medical Diagnostic Prediction App😊 💋💋💋🌹')
st.markdown('Does the Person have Diabetics')

#step1 : load the trained model
model=open('rfc.pickle','rb')
clf=pickle.load(model)
model.close()

#step2: get the user input from frontend

pregs=st.number_input('Pregnancies',0,20,step=1)
glucose=st.slider('Glucose',42,200,40)
bp=st.slider('BloodPressure',20,140,20)
skin=st.slider('SkinThickness',7,99,7)
insulin=st.slider('Insulin',14,850,14)
bmi=st.slider('BMI',18,70,18)
dpf=st.slider('DiabetesPedigreeFunction',0.05,2.50,0.05)
age=st.slider('Age',21,90,21)


#step 3: COnvert user input to model input

data={
    'Pregnancies':pregs,
    'Glucose':glucose,
    'BloodPressure':bp,
    'SkinThickness':skin,
    'Insulin':insulin,
    'BMI':bmi,
    'DiabetesPedigreeFunction':dpf,
    'Age':age
}

input_data=pd.DataFrame([data])

# step4 : get the predictions and print the result
prediction = clf.predict(input_data)[0]
if st.button("Predict"):
    if prediction==0:
        st.write("The Person is Healthy")
    if prediction==1:
        st.write("The Person has Diabetes")
# Out:
# Overwriting app.py
